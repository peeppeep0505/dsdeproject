# %%
import pandas as pd

df = pd.read_csv('finalscrap.csv')

# %%
df.head()
# Out:
#                                                title           authors  \
# 0  Measuring the Queen Bee Phenomenon in technica...  Amornkitvikai Y.
# 1  Growth, total lipid content and fatty acid com...       Thongdet E.
# 2  Innovations in Stroke Identification: A Machin...       Saleem M.A.
# 3  Survival, complications, and patient-reported ...    Sinsareekul C.
# 4  Transnational innovation systems for bioeconom...        Lutta A.I.
#
#                                         affiliations  citedby  \
# 0                Chulalongkorn University (Thailand)        0
# 1  Chulalongkorn University (Thailand); Mahanakor...        0
# 2                Chulalongkorn University (Thailand)        5
# 3                Chulalongkorn University (Thailand)        0
# 4                  World Agroforestry Centre (Kenya)        0
#
#                                            publisher  Year
# 0                                          Routledge  2024
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   object
#  1   authors       1000 non-null   object
#  2   affiliations  1000 non-null   object
#  3   citedby       1000 non-null   int64
#  4   publisher     1000 non-null   object
#  5   Year          1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
df.groupby('affiliations').count()
# Out:
#                                                     title  authors  citedby  \
# affiliations
# Aarhus Universitet (Denmark); Faculty of Medici...      1        1        1
# Abdul Wali Khan University Mardan (Pakistan)            1        1        1
# Academic Teaching Hospital of Johannes Gutenber...      1        1        1
# Adelphi Group (United Kingdom)                          1        1        1
# All India Institute of Medical Sciences, New De...      1        1        1
# ...                                                   ...      ...      ...
# Yerevan Physics Institute (Armenia)                    14       14       14
# Yonsei University (South Korea); PHI Digital He...      1        1        1
# Zewail City of Science and Technology (Egypt); ...      1        1        1
# l'Institut des Maladies Génétiques Imagine (Fra...      1        1        1
# École Polytechnique Fédérale de Lausanne (Switz...      1        1        1
#
# ...

# %%
df['affiliations'].loc[20]
# Out:
# 'ICAR - Central Inland Fisheries Research Institute, Barrackpore (India); Haripal G.D. Institution (India)'
